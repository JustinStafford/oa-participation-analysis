# %%
import pandas as pd
from datetime import datetime, timedelta
from dotenv import load_dotenv
import os, logging

from eventor_api import EventorAPI

logging.basicConfig(level=logging.INFO)

load_dotenv()
api = EventorAPI(os.getenv('API_KEY'))

# %%
def fetch_entries_by_year(api: EventorAPI, start_year: int, end_year: int, output_dir: str = 'data'):
    """
    Fetch entries data progressively and save to yearly CSV files.
    Overwrites existing files to ensure data is up to date.
    
    Args:
        api: EventorAPI instance
        start_year: Starting year (inclusive)
        end_year: Ending year (inclusive)
        output_dir: Directory to save CSV files
    """
    import os
    from pathlib import Path
    from calendar import monthrange
    
    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Process each year
    for year in range(start_year, end_year + 1):
        output_file = os.path.join(output_dir, f'entries_{year}.csv')
        temp_file = os.path.join(output_dir, f'entries_{year}.temp.csv')
        
        logging.info(f"Processing year {year}")
        
        # Initialize empty DataFrame for the year
        yearly_entries = pd.DataFrame()
        
        # Process month by month
        for month in range(1, 13):
            # Get the last day of the month
            _, last_day = monthrange(year, month)
            start_date = datetime(year, month, 1)
            end_date = datetime(year, month, last_day)
            
            logging.info(f"Fetching entries for {start_date.strftime('%B %Y')}")
            
            try:
                # Fetch entries for the current month
                entries_data = api.get_entries(
                    from_event_date=start_date.strftime('%Y-%m-%d'),
                    to_event_date=end_date.strftime('%Y-%m-%d')
                )
                
                # Convert to DataFrame and append
                if entries_data is not None:
                    entries_df = api.entries_to_dataframe(entries_data)
                    yearly_entries = pd.concat([yearly_entries, entries_df], ignore_index=True)
                    
            except Exception as e:
                logging.error(f"Error fetching data for {start_date.strftime('%B %Y')}: {e}")
            
        # Save to temporary file first, then rename to ensure atomic write
        if not yearly_entries.empty:
            yearly_entries = yearly_entries.drop_duplicates(subset=['EntryId'])
            try:
                yearly_entries.to_csv(temp_file, index=False)
                os.replace(temp_file, output_file)  # Atomic operation
                logging.info(f"Saved {len(yearly_entries)} entries for {year} to {output_file}")
            except Exception as e:
                logging.error(f"Error saving file for {year}: {e}")
                if os.path.exists(temp_file):
                    os.remove(temp_file)
        else:
            logging.warning(f"No entries found for {year}")
            # Create empty file to indicate year was processed
            pd.DataFrame().to_csv(output_file, index=False)

# %%
# Example usage
start_year = 2014
end_year = 2024
fetch_entries_by_year(api, start_year, end_year)
# Out:
# INFO:root:Processing year 2014
# INFO:root:Fetching entries for January 2014
# INFO:root:Fetching entries for February 2014
# INFO:root:Fetching entries for March 2014
# INFO:root:Fetching entries for April 2014
# INFO:root:Fetching entries for May 2014
# INFO:root:Fetching entries for June 2014
# INFO:root:Fetching entries for July 2014
# INFO:root:Fetching entries for August 2014
# INFO:root:Fetching entries for September 2014
# INFO:root:Fetching entries for October 2014
# INFO:root:Fetching entries for November 2014
# INFO:root:Fetching entries for December 2014
# INFO:root:Saved 44030 entries for 2014 to data/entries_2014.csv
# INFO:root:Processing year 2015
# INFO:root:Fetching entries for January 2015
# INFO:root:Fetching entries for February 2015
# INFO:root:Fetching entries for March 2015
# INFO:root:Fetching entries for April 2015
# INFO:root:Fetching entries for May 2015
# INFO:root:Fetching entries for June 2015
# INFO:root:Fetching entries for July 2015
# INFO:root:Fetching entries for August 2015
# INFO:root:Fetching entries for September 2015
# INFO:root:Fetching entries for October 2015
# INFO:root:Fetching entries for November 2015
# INFO:root:Fetching entries for December 2015
# INFO:root:Saved 25621 entries for 2015 to data/entries_2015.csv
# INFO:root:Processing year 2016
# INFO:root:Fetching entries for January 2016
# INFO:root:Fetching entries for February 2016
# INFO:root:Fetching entries for March 2016
# INFO:root:Fetching entries for April 2016
# INFO:root:Fetching entries for May 2016
# INFO:root:Fetching entries for June 2016
# INFO:root:Fetching entries for July 2016
# INFO:root:Fetching entries for August 2016
# INFO:root:Fetching entries for September 2016
# INFO:root:Fetching entries for October 2016
# INFO:root:Fetching entries for November 2016
# INFO:root:Fetching entries for December 2016
# INFO:root:Saved 22214 entries for 2016 to data/entries_2016.csv
# INFO:root:Processing year 2017
# INFO:root:Fetching entries for January 2017
# INFO:root:Fetching entries for February 2017
# INFO:root:Fetching entries for March 2017
# INFO:root:Fetching entries for April 2017
# INFO:root:Fetching entries for May 2017
# INFO:root:Fetching entries for June 2017
# INFO:root:Fetching entries for July 2017
# INFO:root:Fetching entries for August 2017
# INFO:root:Fetching entries for September 2017
# INFO:root:Fetching entries for October 2017
# INFO:root:Fetching entries for November 2017
# INFO:root:Fetching entries for December 2017
# INFO:root:Saved 20503 entries for 2017 to data/entries_2017.csv
# INFO:root:Processing year 2018
# INFO:root:Fetching entries for January 2018
# INFO:root:Fetching entries for February 2018
# INFO:root:Fetching entries for March 2018
# INFO:root:Fetching entries for April 2018
# INFO:root:Fetching entries for May 2018
# INFO:root:Fetching entries for June 2018
# INFO:root:Fetching entries for July 2018
# INFO:root:Fetching entries for August 2018
# INFO:root:Fetching entries for September 2018
# INFO:root:Fetching entries for October 2018
# INFO:root:Fetching entries for November 2018
# INFO:root:Fetching entries for December 2018
# INFO:root:Saved 25450 entries for 2018 to data/entries_2018.csv
# INFO:root:Processing year 2019
# INFO:root:Fetching entries for January 2019
# INFO:root:Fetching entries for February 2019
# INFO:root:Fetching entries for March 2019
# INFO:root:Fetching entries for April 2019
# INFO:root:Fetching entries for May 2019
# INFO:root:Fetching entries for June 2019
# INFO:root:Fetching entries for July 2019
# INFO:root:Fetching entries for August 2019
# INFO:root:Fetching entries for September 2019
# INFO:root:Fetching entries for October 2019
# INFO:root:Fetching entries for November 2019
# INFO:root:Fetching entries for December 2019
# INFO:root:Saved 26439 entries for 2019 to data/entries_2019.csv
# INFO:root:Processing year 2020
# INFO:root:Fetching entries for January 2020
# INFO:root:Fetching entries for February 2020
# INFO:root:Fetching entries for March 2020
# INFO:root:Fetching entries for April 2020
# INFO:root:Fetching entries for May 2020
# INFO:root:Fetching entries for June 2020
# INFO:root:Fetching entries for July 2020
# INFO:root:Fetching entries for August 2020
# INFO:root:Fetching entries for September 2020
# INFO:root:Fetching entries for October 2020
# INFO:root:Fetching entries for November 2020
# INFO:root:Fetching entries for December 2020
# INFO:root:Saved 24773 entries for 2020 to data/entries_2020.csv
# INFO:root:Processing year 2021
# INFO:root:Fetching entries for January 2021
# INFO:root:Fetching entries for February 2021
# INFO:root:Fetching entries for March 2021
# INFO:root:Fetching entries for April 2021
# INFO:root:Fetching entries for May 2021
# INFO:root:Fetching entries for June 2021
# INFO:root:Fetching entries for July 2021
# INFO:root:Fetching entries for August 2021
# INFO:root:Fetching entries for September 2021
# INFO:root:Fetching entries for October 2021
# INFO:root:Fetching entries for November 2021
# INFO:root:Fetching entries for December 2021
# INFO:root:Saved 39230 entries for 2021 to data/entries_2021.csv
# INFO:root:Processing year 2022
# INFO:root:Fetching entries for January 2022
# INFO:root:Fetching entries for February 2022
# INFO:root:Fetching entries for March 2022
# INFO:root:Fetching entries for April 2022
# INFO:root:Fetching entries for May 2022
# INFO:root:Fetching entries for June 2022
# INFO:root:Fetching entries for July 2022
# INFO:root:Fetching entries for August 2022
# INFO:root:Fetching entries for September 2022
# INFO:root:Fetching entries for October 2022
# INFO:root:Fetching entries for November 2022
# INFO:root:Fetching entries for December 2022
# INFO:root:Saved 44352 entries for 2022 to data/entries_2022.csv
# INFO:root:Processing year 2023
# INFO:root:Fetching entries for January 2023
# INFO:root:Fetching entries for February 2023
# INFO:root:Fetching entries for March 2023
# INFO:root:Fetching entries for April 2023
# INFO:root:Fetching entries for May 2023
# INFO:root:Fetching entries for June 2023
# INFO:root:Fetching entries for July 2023
# INFO:root:Fetching entries for August 2023
# INFO:root:Fetching entries for September 2023
# INFO:root:Fetching entries for October 2023
# INFO:root:Fetching entries for November 2023
# INFO:root:Fetching entries for December 2023
# INFO:root:Saved 43311 entries for 2023 to data/entries_2023.csv
# INFO:root:Processing year 2024
# INFO:root:Fetching entries for January 2024
# INFO:root:Fetching entries for February 2024
# INFO:root:Fetching entries for March 2024
# INFO:root:Fetching entries for April 2024
# INFO:root:Fetching entries for May 2024
# INFO:root:Fetching entries for June 2024
# INFO:root:Fetching entries for July 2024
# INFO:root:Fetching entries for August 2024
# INFO:root:Fetching entries for September 2024
# INFO:root:Fetching entries for October 2024
# INFO:root:Fetching entries for November 2024
# INFO:root:Fetching entries for December 2024
# INFO:root:Saved 44941 entries for 2024 to data/entries_2024.csv
